# %% [markdown]
# # Gemini PDF worker

# %%
# ─── Imports ────────────────────────────────────────────────────────────────
import json, base64, os
from dotenv import load_dotenv
from pypdf import PdfReader
from google import genai
from google.genai import types

# %%
# ─── Setup ────────────────────────────────────────────────────────────────
MODEL = "gemini-2.5-flash-preview-04-17"

load_dotenv(dotenv_path=".env.local")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=GEMINI_API_KEY)

# %%
# ─── Helpers ──────────────────────────────────────────────────────────────
def extract_fields_with_coords(pdf_path):
    reader = PdfReader(pdf_path)
    fields = []
    for page_num, page in enumerate(reader.pages, start=1):
        for annot in page.get("/Annots", []):
            obj = annot.get_object()
            name = obj.get("/T")
            rect = obj.get("/Rect")
            if name and rect:
                x1, y1, x2, y2 = rect
                fields.append({
                    "field_id": name,
                    "page":     page_num,
                    "coords":   [x1, y1, x2, y2],
                })
    return fields

# %%
# ─── Real Gemini Call ─────────────────────────────────────────────────────
def enrich_fields_with_gemini(raw_fields, instructions_path, language="en"):
    # 1) Read & encode instructions PDF
    with open(instructions_path, "rb") as f:
        inst_b64 = base64.b64encode(f.read()).decode("utf-8")

    # 2) Build your prompt (JSON-in, JSON-out)
    prompt = f"""
I have a USCIS form with these fields (field_id, page, coords):
{json.dumps(raw_fields, indent=2)}

I also have the form instructions PDF encoded in base64:
{inst_b64}

Please, for each field, output a JSON object with keys:
  - field_id
  - label           (short human label)
  - page
  - coords
  - dependencies    (list of other field_ids)
  - gemini_note     (plain-English explanation)
  - examples        (list with one example)
Return strictly valid JSON in the format: {{ "fields": [ ... ] }}.
Language: {language}
"""

    # 3) Call Gemini
    response = client.models.generate_content(
        model=MODEL,
        contents=[
            types.Content(
                role="user", 
                parts=[ 
                    types.Part.from_text(text=prompt) 
                ]
            )
        ],
        config=types.GenerateContentConfig(
            thinking_config=types.ThinkingConfig(thinking_budget=0),
            response_mime_type="application/json",
        )
    )

    # 4) Parse & return
    result = json.loads(response.text)
    return result["fields"]

# %%
form_pdf = "static/forms/I-765/form.pdf"
inst_pdf = "static/forms/I-765/inst.pdf"

raw = extract_fields_with_coords(form_pdf)
enriched = enrich_fields_with_gemini(raw, inst_pdf, language="en")

print(json.dumps(enriched, indent=2))
# Out:
# [
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 1,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Line1a_FamilyName[0]",
#     "label": "Family Name",
#     "page": 1,
#     "coords": [
#       120.002,
#       132.001,
#       294.001,
#       150.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's family name.",
#     "examples": [
#       "SMITH"
#     ]
#   },
#   {
#     "field_id": "Line1b_GivenName[0]",
#     "label": "Given Name",
#     "page": 1,
#     "coords": [
#       120.002,
#       108.006,
#       294.001,
#       126.006
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's given name.",
#     "examples": [
#       "JOHN"
#     ]
#   },
#   {
#     "field_id": "Line1c_MiddleName[0]",
#     "label": "Middle Name",
#     "page": 1,
#     "coords": [
#       120.002,
#       84.005,
#       294.001,
#       102.005
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's middle name.",
#     "examples": [
#       "PAUL"
#     ]
#   },
#   {
#     "field_id": "Part1_Checkbox[0]",
#     "label": "Part 1 Checkbox",
#     "page": 1,
#     "coords": [
#       61.0,
#       409.002,
#       71.0,
#       419.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 1.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part1_Checkbox[1]",
#     "label": "Part 1 Checkbox",
#     "page": 1,
#     "coords": [
#       61.0,
#       391.002,
#       71.0,
#       401.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 1.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part1_Checkbox[2]",
#     "label": "Part 1 Checkbox",
#     "page": 1,
#     "coords": [
#       61.0,
#       246.999,
#       71.0,
#       256.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 1.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "CheckBox1[0]",
#     "label": "Checkbox 1",
#     "page": 1,
#     "coords": [
#       246.501,
#       529.001,
#       256.501,
#       539.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line2a_FamilyName[0]",
#     "label": "Part 2 Family Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       366.001,
#       576.0,
#       384.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's family name in Part 2.",
#     "examples": [
#       "DOE"
#     ]
#   },
#   {
#     "field_id": "Line2b_GivenName[0]",
#     "label": "Part 2 Given Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       342.006,
#       576.0,
#       360.006
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's given name in Part 2.",
#     "examples": [
#       "JANE"
#     ]
#   },
#   {
#     "field_id": "Line2c_MiddleName[0]",
#     "label": "Part 2 Middle Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       318.005,
#       576.0,
#       336.005
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's middle name in Part 2.",
#     "examples": [
#       "ANN"
#     ]
#   },
#   {
#     "field_id": "Line3c_MiddleName[0]",
#     "label": "Part 3 Middle Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       162.003,
#       576.0,
#       180.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "MARIE"
#     ]
#   },
#   {
#     "field_id": "Line3b_GivenName[0]",
#     "label": "Part 3 Given Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       186.004,
#       576.0,
#       204.004
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "ALICE"
#     ]
#   },
#   {
#     "field_id": "Line3a_FamilyName[0]",
#     "label": "Part 3 Family Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       209.999,
#       576.0,
#       227.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "BROWN"
#     ]
#   },
#   {
#     "field_id": "Line3a_FamilyName[1]",
#     "label": "Part 3 Family Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       288.0,
#       576.0,
#       306.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "GREEN"
#     ]
#   },
#   {
#     "field_id": "Line3b_GivenName[1]",
#     "label": "Part 3 Given Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       264.005,
#       576.0,
#       282.005
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "DAVID"
#     ]
#   },
#   {
#     "field_id": "Line3c_MiddleName[1]",
#     "label": "Part 3 Middle Name",
#     "page": 1,
#     "coords": [
#       402.001,
#       240.004,
#       576.0,
#       258.004
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 3, potentially an alias or previous name.",
#     "examples": [
#       "LEE"
#     ]
#   },
#   {
#     "field_id": "USCISELISAcctNumber[0]",
#     "label": "USCIS ELIS Account Number",
#     "page": 1,
#     "coords": [
#       396.0,
#       497.951,
#       570.01,
#       515.951
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's USCIS ELIS online account number.",
#     "examples": [
#       "IOE1234567890"
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 2,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Part2Line5_Checkbox[0]",
#     "label": "Part 2 Line 5 Checkbox",
#     "page": 2,
#     "coords": [
#       260.161,
#       514.001,
#       270.161,
#       524.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 5, likely related to an address type.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part2Line5_Checkbox[1]",
#     "label": "Part 2 Line 5 Checkbox",
#     "page": 2,
#     "coords": [
#       218.16,
#       514.001,
#       228.16,
#       524.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 5, likely related to an address type.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_Unit[0]",
#     "label": "Part 2 Line 7 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       101.999,
#       405.998,
#       111.999,
#       415.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 7, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_Unit[1]",
#     "label": "Part 2 Line 7 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       144.0,
#       405.998,
#       154.0,
#       415.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 7, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_AptSteFlrNumber[0]",
#     "label": "Part 2 Line 7 Apt/Ste/Flr Number",
#     "page": 2,
#     "coords": [
#       186.001,
#       401.998,
#       294.001,
#       419.998
#     ],
#     "dependencies": [
#       "Pt2Line7_Unit[0]",
#       "Pt2Line7_Unit[1]",
#       "Pt2Line7_Unit[2]"
#     ],
#     "gemini_note": "This field is for the apartment, suite, or floor number for the address in Part 2, Line 7.",
#     "examples": [
#       "APT 101"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_Unit[2]",
#     "label": "Part 2 Line 7 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       60.001,
#       406.001,
#       70.001,
#       416.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 7, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_CityOrTown[0]",
#     "label": "Part 2 Line 7 City or Town",
#     "page": 2,
#     "coords": [
#       126.0,
#       378.0,
#       294.001,
#       396.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town for the address in Part 2, Line 7.",
#     "examples": [
#       "NEW YORK"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_State[0]",
#     "label": "Part 2 Line 7 State",
#     "page": 2,
#     "coords": [
#       84.002,
#       354.002,
#       120.002,
#       372.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the state for the address in Part 2, Line 7.",
#     "examples": [
#       "NY"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_ZipCode[0]",
#     "label": "Part 2 Line 7 Zip Code",
#     "page": 2,
#     "coords": [
#       192.002,
#       354.002,
#       294.001,
#       372.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the zip code for the address in Part 2, Line 7.",
#     "examples": [
#       "10001"
#     ]
#   },
#   {
#     "field_id": "Pt2Line7_StreetNumberName[0]",
#     "label": "Part 2 Line 7 Street Number and Name",
#     "page": 2,
#     "coords": [
#       126.0,
#       426.002,
#       294.001,
#       444.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the street number and name for the address in Part 2, Line 7.",
#     "examples": [
#       "123 MAIN ST"
#     ]
#   },
#   {
#     "field_id": "Line14_Checkbox_No[0]",
#     "label": "Line 14 Checkbox No",
#     "page": 2,
#     "coords": [
#       542.157,
#       538.002,
#       552.157,
#       548.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is the 'No' checkbox for Line 14.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line14_Checkbox_Yes[0]",
#     "label": "Line 14 Checkbox Yes",
#     "page": 2,
#     "coords": [
#       500.159,
#       538.002,
#       510.159,
#       548.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is the 'Yes' checkbox for Line 14.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line7_AlienNumber[0]",
#     "label": "Part 2 Line 7 Alien Number",
#     "page": 2,
#     "coords": [
#       163.191,
#       288.0,
#       293.831,
#       306.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's Alien Registration Number (A-Number) in Part 2, Line 7.",
#     "examples": [
#       "A123456789"
#     ]
#   },
#   {
#     "field_id": "Line8_ElisAccountNumber[0]",
#     "label": "Part 2 Line 8 ELIS Account Number",
#     "page": 2,
#     "coords": [
#       120.008,
#       252.0,
#       294.018,
#       270.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's USCIS ELIS online account number in Part 2, Line 8.",
#     "examples": [
#       "IOE9876543210"
#     ]
#   },
#   {
#     "field_id": "Line9_Checkbox[0]",
#     "label": "Part 2 Line 9 Checkbox",
#     "page": 2,
#     "coords": [
#       245.999,
#       232.002,
#       255.999,
#       242.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 9.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line9_Checkbox[1]",
#     "label": "Part 2 Line 9 Checkbox",
#     "page": 2,
#     "coords": [
#       198.0,
#       232.002,
#       208.0,
#       242.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 9.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line10_Checkbox[0]",
#     "label": "Part 2 Line 10 Checkbox",
#     "page": 2,
#     "coords": [
#       240.001,
#       195.999,
#       250.001,
#       205.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 10.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line10_Checkbox[1]",
#     "label": "Part 2 Line 10 Checkbox",
#     "page": 2,
#     "coords": [
#       173.999,
#       195.999,
#       183.999,
#       205.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 10.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line10_Checkbox[2]",
#     "label": "Part 2 Line 10 Checkbox",
#     "page": 2,
#     "coords": [
#       60.001,
#       195.999,
#       70.001,
#       205.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 10.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line10_Checkbox[3]",
#     "label": "Part 2 Line 10 Checkbox",
#     "page": 2,
#     "coords": [
#       114.001,
#       195.999,
#       124.001,
#       205.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 10.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line19_Checkbox[0]",
#     "label": "Part 2 Line 19 Checkbox",
#     "page": 2,
#     "coords": [
#       260.158,
#       160.002,
#       270.158,
#       170.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 19.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line19_Checkbox[1]",
#     "label": "Part 2 Line 19 Checkbox",
#     "page": 2,
#     "coords": [
#       218.16,
#       159.857,
#       228.16,
#       169.857
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 19.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line15a_FamilyName[0]",
#     "label": "Part 2 Line 15a Family Name",
#     "page": 2,
#     "coords": [
#       402.001,
#       432.145,
#       576.0,
#       450.145
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 2, Line 15, likely the applicant's name again.",
#     "examples": [
#       "SMITH"
#     ]
#   },
#   {
#     "field_id": "Line15b_GivenName[0]",
#     "label": "Part 2 Line 15b Given Name",
#     "page": 2,
#     "coords": [
#       402.001,
#       408.149,
#       576.0,
#       426.149
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 2, Line 15, likely the applicant's name again.",
#     "examples": [
#       "JOHN"
#     ]
#   },
#   {
#     "field_id": "Line16a_FamilyName[0]",
#     "label": "Part 2 Line 16a Family Name",
#     "page": 2,
#     "coords": [
#       402.001,
#       342.0,
#       576.0,
#       360.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 2, Line 16, potentially a previous name.",
#     "examples": [
#       "DOE"
#     ]
#   },
#   {
#     "field_id": "Line16b_GivenName[0]",
#     "label": "Part 2 Line 16b Given Name",
#     "page": 2,
#     "coords": [
#       402.001,
#       318.005,
#       576.0,
#       336.005
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a name in Part 2, Line 16, potentially a previous name.",
#     "examples": [
#       "JANE"
#     ]
#   },
#   {
#     "field_id": "Line17b_CountryOfBirth[0]",
#     "label": "Part 2 Line 17b Country of Birth",
#     "page": 2,
#     "coords": [
#       342.0,
#       155.999,
#       576.0,
#       173.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's country of birth in Part 2, Line 17b.",
#     "examples": [
#       "MEXICO"
#     ]
#   },
#   {
#     "field_id": "Line17a_CountryOfBirth[0]",
#     "label": "Part 2 Line 17a Country of Birth",
#     "page": 2,
#     "coords": [
#       342.0,
#       191.999,
#       576.0,
#       209.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's country of birth in Part 2, Line 17a.",
#     "examples": [
#       "CANADA"
#     ]
#   },
#   {
#     "field_id": "Line13_Checkbox[0]",
#     "label": "Part 2 Line 13 Checkbox",
#     "page": 2,
#     "coords": [
#       542.157,
#       651.997,
#       552.157,
#       661.997
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 13.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line13_Checkbox[1]",
#     "label": "Part 2 Line 13 Checkbox",
#     "page": 2,
#     "coords": [
#       500.159,
#       651.997,
#       510.159,
#       661.997
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 13.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line12b_SSN[0]",
#     "label": "Part 2 Line 12b Social Security Number",
#     "page": 2,
#     "coords": [
#       446.947,
#       708.001,
#       575.957,
#       726.001
#     ],
#     "dependencies": [
#       "Line12a_Checkbox[0]",
#       "Line12a_Checkbox[1]"
#     ],
#     "gemini_note": "This field is for the applicant's Social Security Number (SSN) in Part 2, Line 12b, if applicable.",
#     "examples": [
#       "999-88-7777"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_Unit[0]",
#     "label": "Part 2 Line 5 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       102.002,
#       609.996,
#       112.002,
#       619.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 5, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_Unit[1]",
#     "label": "Part 2 Line 5 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       144.0,
#       609.996,
#       154.0,
#       619.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 5, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_AptSteFlrNumber[0]",
#     "label": "Part 2 Line 5 Apt/Ste/Flr Number",
#     "page": 2,
#     "coords": [
#       186.001,
#       605.996,
#       294.001,
#       623.996
#     ],
#     "dependencies": [
#       "Pt2Line5_Unit[0]",
#       "Pt2Line5_Unit[1]",
#       "Pt2Line5_Unit[2]"
#     ],
#     "gemini_note": "This field is for the apartment, suite, or floor number for the address in Part 2, Line 5.",
#     "examples": [
#       "APT 202"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_Unit[2]",
#     "label": "Part 2 Line 5 Unit Checkbox",
#     "page": 2,
#     "coords": [
#       60.001,
#       609.999,
#       70.001,
#       619.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 5, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_CityOrTown[0]",
#     "label": "Part 2 Line 5 City or Town",
#     "page": 2,
#     "coords": [
#       126.0,
#       581.998,
#       294.001,
#       599.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town for the address in Part 2, Line 5.",
#     "examples": [
#       "LOS ANGELES"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_State[0]",
#     "label": "Part 2 Line 5 State",
#     "page": 2,
#     "coords": [
#       84.002,
#       558.0,
#       120.002,
#       576.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the state for the address in Part 2, Line 5.",
#     "examples": [
#       "CA"
#     ]
#   },
#   {
#     "field_id": "Pt2Line5_ZipCode[0]",
#     "label": "Part 2 Line 5 Zip Code",
#     "page": 2,
#     "coords": [
#       192.002,
#       558.0,
#       294.001,
#       576.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the zip code for the address in Part 2, Line 5.",
#     "examples": [
#       "90210"
#     ]
#   },
#   {
#     "field_id": "Line4b_StreetNumberName[0]",
#     "label": "Part 2 Line 4b Street Number and Name",
#     "page": 2,
#     "coords": [
#       126.0,
#       630.0,
#       294.001,
#       648.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the street number and name for the address in Part 2, Line 4b.",
#     "examples": [
#       "456 OAK AVE"
#     ]
#   },
#   {
#     "field_id": "Line4a_InCareofName[0]",
#     "label": "Part 2 Line 4a In Care Of Name",
#     "page": 2,
#     "coords": [
#       60.001,
#       653.998,
#       294.106,
#       671.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the 'In Care Of' name for the mailing address in Part 2, Line 4a.",
#     "examples": [
#       "JOHN SMITH"
#     ]
#   },
#   {
#     "field_id": "Line12a_Checkbox[0]",
#     "label": "Part 2 Line 12a Checkbox",
#     "page": 2,
#     "coords": [
#       260.158,
#       112.003,
#       270.158,
#       122.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 12a, related to the applicant's SSN.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line12a_Checkbox[1]",
#     "label": "Part 2 Line 12a Checkbox",
#     "page": 2,
#     "coords": [
#       218.16,
#       112.003,
#       228.16,
#       122.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 2, Line 12a, related to the applicant's SSN.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 3,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Line20c_TravelDoc[0]",
#     "label": "Part 3 Line 20c Travel Document Number",
#     "page": 3,
#     "coords": [
#       60.001,
#       372.002,
#       294.001,
#       390.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's travel document number in Part 3, Line 20c.",
#     "examples": [
#       "TD123456"
#     ]
#   },
#   {
#     "field_id": "Line21_DateOfLastEntry[0]",
#     "label": "Part 3 Line 21 Date of Last Entry",
#     "page": 3,
#     "coords": [
#       198.0,
#       264.002,
#       294.001,
#       282.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the date of the applicant's last entry into the U.S. in Part 3, Line 21.",
#     "examples": [
#       "01/01/2023"
#     ]
#   },
#   {
#     "field_id": "Line20e_ExpDate[0]",
#     "label": "Part 3 Line 20e Travel Document Expiration Date",
#     "page": 3,
#     "coords": [
#       198.0,
#       300.008,
#       294.001,
#       318.008
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the expiration date of the applicant's travel document in Part 3, Line 20e.",
#     "examples": [
#       "12/31/2025"
#     ]
#   },
#   {
#     "field_id": "Line20d_CountryOfIssuance[0]",
#     "label": "Part 3 Line 20d Country of Issuance",
#     "page": 3,
#     "coords": [
#       60.001,
#       336.005,
#       294.001,
#       354.005
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the country that issued the applicant's travel document in Part 3, Line 20d.",
#     "examples": [
#       "MEXICO"
#     ]
#   },
#   {
#     "field_id": "Line20b_Passport[0]",
#     "label": "Part 3 Line 20b Passport Number",
#     "page": 3,
#     "coords": [
#       60.001,
#       408.008,
#       294.001,
#       426.008
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's passport number in Part 3, Line 20b.",
#     "examples": [
#       "P123456789"
#     ]
#   },
#   {
#     "field_id": "Line23_StatusLastEntry[0]",
#     "label": "Part 3 Line 23 Status at Last Entry",
#     "page": 3,
#     "coords": [
#       60.001,
#       180.0,
#       294.001,
#       198.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's immigration status at their last entry into the U.S. in Part 3, Line 23.",
#     "examples": [
#       "B2"
#     ]
#   },
#   {
#     "field_id": "Line24_CurrentStatus[0]",
#     "label": "Part 3 Line 24 Current Immigration Status",
#     "page": 3,
#     "coords": [
#       60.001,
#       119.999,
#       294.001,
#       137.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's current immigration status in Part 3, Line 24.",
#     "examples": [
#       "F1"
#     ]
#   },
#   {
#     "field_id": "Line26_SEVISnumber[0]",
#     "label": "Part 3 Line 26 SEVIS Number",
#     "page": 3,
#     "coords": [
#       162.0,
#       72.0,
#       294.001,
#       90.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's SEVIS number in Part 3, Line 26, if applicable.",
#     "examples": [
#       "N0001234567"
#     ]
#   },
#   {
#     "field_id": "Line27b_Everify[0]",
#     "label": "Part 3 Line 27b E-Verify Company ID Number",
#     "page": 3,
#     "coords": [
#       342.0,
#       522.003,
#       576.0,
#       540.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the E-Verify Company Identification Number in Part 3, Line 27b.",
#     "examples": [
#       "123456"
#     ]
#   },
#   {
#     "field_id": "Line27c_EverifyIDNumber[0]",
#     "label": "Part 3 Line 27c E-Verify Case Number",
#     "page": 3,
#     "coords": [
#       342.0,
#       474.001,
#       576.0,
#       492.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the E-Verify Case Number in Part 3, Line 27c, if applicable.",
#     "examples": [
#       "C1234567890"
#     ]
#   },
#   {
#     "field_id": "PtLine29_YesNo[0]",
#     "label": "Part 3 Line 29 Yes/No Checkbox",
#     "page": 3,
#     "coords": [
#       500.159,
#       333.998,
#       510.159,
#       343.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 29, for a Yes/No question.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "PtLine29_YesNo[1]",
#     "label": "Part 3 Line 29 Yes/No Checkbox",
#     "page": 3,
#     "coords": [
#       541.919,
#       333.998,
#       551.919,
#       343.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 29, for a Yes/No question.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Line30a_ReceiptNumber[0]",
#     "label": "Part 3 Line 30a Receipt Number",
#     "page": 3,
#     "coords": [
#       388.001,
#       155.999,
#       576.403,
#       173.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a receipt number in Part 3, Line 30a.",
#     "examples": [
#       "SRC1234567890"
#     ]
#   },
#   {
#     "field_id": "Line28_ReceiptNumber[0]",
#     "label": "Part 3 Line 28 Receipt Number",
#     "page": 3,
#     "coords": [
#       387.598,
#       389.996,
#       576.0,
#       407.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a receipt number in Part 3, Line 28.",
#     "examples": [
#       "LIN9876543210"
#     ]
#   },
#   {
#     "field_id": "Line27a_Degree[0]",
#     "label": "Part 3 Line 27a Degree",
#     "page": 3,
#     "coords": [
#       378.0,
#       558.0,
#       576.0,
#       576.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's degree in Part 3, Line 27a.",
#     "examples": [
#       "BACHELOR'S DEGREE"
#     ]
#   },
#   {
#     "field_id": "Line20a_I94Number[0]",
#     "label": "Part 3 Line 20a I-94 Number",
#     "page": 3,
#     "coords": [
#       132.001,
#       443.999,
#       292.107,
#       461.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's I-94 Arrival-Departure Record number in Part 3, Line 20a.",
#     "examples": [
#       "12345678901"
#     ]
#   },
#   {
#     "field_id": "Line19_DOB[0]",
#     "label": "Part 3 Line 19 Date of Birth",
#     "page": 3,
#     "coords": [
#       210.002,
#       528.001,
#       294.004,
#       546.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's date of birth in Part 3, Line 19.",
#     "examples": [
#       "05/15/1990"
#     ]
#   },
#   {
#     "field_id": "Line18c_CountryOfBirth[0]",
#     "label": "Part 3 Line 18c Country of Birth",
#     "page": 3,
#     "coords": [
#       60.001,
#       551.996,
#       294.001,
#       569.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the country of birth in Part 3, Line 18c.",
#     "examples": [
#       "CHINA"
#     ]
#   },
#   {
#     "field_id": "Line18a_CityTownOfBirth[0]",
#     "label": "Part 3 Line 18a City/Town of Birth",
#     "page": 3,
#     "coords": [
#       60.001,
#       623.999,
#       293.817,
#       641.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town of birth in Part 3, Line 18a.",
#     "examples": [
#       "BEIJING"
#     ]
#   },
#   {
#     "field_id": "Line18b_CityTownOfBirth[0]",
#     "label": "Part 3 Line 18b City/Town of Birth",
#     "page": 3,
#     "coords": [
#       60.185,
#       587.996,
#       294.001,
#       605.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town of birth in Part 3, Line 18b.",
#     "examples": [
#       "SHANGHAI"
#     ]
#   },
#   {
#     "field_id": "section_1[0]",
#     "label": "Part 3 Section 1",
#     "page": 3,
#     "coords": [
#       474.001,
#       636.001,
#       497.999,
#       654.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for Section 1 in Part 3.",
#     "examples": [
#       "1"
#     ]
#   },
#   {
#     "field_id": "section_2[0]",
#     "label": "Part 3 Section 2",
#     "page": 3,
#     "coords": [
#       510.001,
#       636.001,
#       533.999,
#       654.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for Section 2 in Part 3.",
#     "examples": [
#       "2"
#     ]
#   },
#   {
#     "field_id": "section_3[0]",
#     "label": "Part 3 Section 3",
#     "page": 3,
#     "coords": [
#       546.001,
#       636.001,
#       569.999,
#       654.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for Section 3 in Part 3.",
#     "examples": [
#       "3"
#     ]
#   },
#   {
#     "field_id": "PtLine30b_YesNo[0]",
#     "label": "Part 3 Line 30b Yes/No Checkbox",
#     "page": 3,
#     "coords": [
#       500.159,
#       112.0,
#       510.159,
#       122.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 30b, for a Yes/No question.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "PtLine30b_YesNo[1]",
#     "label": "Part 3 Line 30b Yes/No Checkbox",
#     "page": 3,
#     "coords": [
#       541.919,
#       112.0,
#       551.919,
#       122.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 30b, for a Yes/No question.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "place_entry[0]",
#     "label": "Part 3 Place of Last Entry",
#     "page": 3,
#     "coords": [
#       60.001,
#       227.999,
#       294.001,
#       245.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the place of the applicant's last entry into the U.S. in Part 3.",
#     "examples": [
#       "NEW YORK, NY"
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 4,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Pt3Line1Checkbox[0]",
#     "label": "Part 3 Line 1 Checkbox",
#     "page": 4,
#     "coords": [
#       61.003,
#       529.001,
#       71.003,
#       539.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 1.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt3Line1Checkbox[1]",
#     "label": "Part 3 Line 1 Checkbox",
#     "page": 4,
#     "coords": [
#       61.003,
#       571.002,
#       71.003,
#       581.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3, Line 1.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt3Line1b_Language[0]",
#     "label": "Part 3 Line 1b Language",
#     "page": 4,
#     "coords": [
#       78.004,
#       486.0,
#       288.003,
#       504.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the language spoken by the applicant in Part 3, Line 1b.",
#     "examples": [
#       "SPANISH"
#     ]
#   },
#   {
#     "field_id": "Part3_Checkbox[0]",
#     "label": "Part 3 Checkbox",
#     "page": 4,
#     "coords": [
#       61.0,
#       444.999,
#       71.0,
#       454.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 3.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt3Line2_RepresentativeName[0]",
#     "label": "Part 3 Line 2 Representative Name",
#     "page": 4,
#     "coords": [
#       78.001,
#       425.999,
#       288.0,
#       443.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the name of the applicant's representative in Part 3, Line 2.",
#     "examples": [
#       "JANE DOE"
#     ]
#   },
#   {
#     "field_id": "Pt3Line7b_DateofSignature[0]",
#     "label": "Part 3 Line 7b Date of Signature",
#     "page": 4,
#     "coords": [
#       492.001,
#       306.0,
#       576.003,
#       324.0
#     ],
#     "dependencies": [
#       "Pt3Line7a_Signature[0]"
#     ],
#     "gemini_note": "This field is for the date the applicant signed the form in Part 3, Line 7b.",
#     "examples": [
#       "03/07/2024"
#     ]
#   },
#   {
#     "field_id": "Pt3Line7a_Signature[0]",
#     "label": "Part 3 Line 7a Signature",
#     "page": 4,
#     "coords": [
#       342.0,
#       330.001,
#       576.0,
#       348.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's signature in Part 3, Line 7a.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Pt3Line3_DaytimePhoneNumber1[0]",
#     "label": "Part 3 Line 3 Daytime Phone Number",
#     "page": 4,
#     "coords": [
#       59.893,
#       335.999,
#       294.227,
#       353.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a daytime phone number in Part 3, Line 3.",
#     "examples": [
#       "555-555-5555"
#     ]
#   },
#   {
#     "field_id": "Pt3Line4_MobileNumber1[0]",
#     "label": "Part 3 Line 4 Mobile Phone Number",
#     "page": 4,
#     "coords": [
#       59.893,
#       300.002,
#       294.227,
#       318.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for a mobile phone number in Part 3, Line 4.",
#     "examples": [
#       "555-111-2222"
#     ]
#   },
#   {
#     "field_id": "Pt3Line5_Email[0]",
#     "label": "Part 3 Line 5 Email Address",
#     "page": 4,
#     "coords": [
#       60.001,
#       263.999,
#       294.001,
#       281.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for an email address in Part 3, Line 5.",
#     "examples": [
#       "johndoe@email.com"
#     ]
#   },
#   {
#     "field_id": "Pt4Line6_Checkbox[0]",
#     "label": "Part 4 Line 6 Checkbox",
#     "page": 4,
#     "coords": [
#       61.0,
#       246.999,
#       71.0,
#       256.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 4, Line 6.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt4Line2_InterpreterBusinessorOrg[0]",
#     "label": "Part 4 Line 2 Interpreter Business or Organization Name",
#     "page": 4,
#     "coords": [
#       342.0,
#       54.0,
#       575.532,
#       72.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's business or organization name in Part 4, Line 2.",
#     "examples": [
#       "LANGUAGE SERVICES INC."
#     ]
#   },
#   {
#     "field_id": "Pt4Line1b_InterpreterGivenName[0]",
#     "label": "Part 4 Line 1b Interpreter Given Name",
#     "page": 4,
#     "coords": [
#       342.0,
#       90.0,
#       575.532,
#       108.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's given name in Part 4, Line 1b.",
#     "examples": [
#       "MARY"
#     ]
#   },
#   {
#     "field_id": "Pt4Line1a_InterpreterFamilyName[0]",
#     "label": "Part 4 Line 1a Interpreter Family Name",
#     "page": 4,
#     "coords": [
#       342.468,
#       126.0,
#       576.0,
#       144.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's family name in Part 4, Line 1a.",
#     "examples": [
#       "JOHNSON"
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 5,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Pt4Line4_InterpreterDaytimeTelephone[0]",
#     "label": "Part 4 Line 4 Interpreter Daytime Telephone Number",
#     "page": 5,
#     "coords": [
#       60.001,
#       426.002,
#       294.001,
#       444.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's daytime telephone number in Part 4, Line 4.",
#     "examples": [
#       "555-333-4444"
#     ]
#   },
#   {
#     "field_id": "Pt4Line6_Email[0]",
#     "label": "Part 4 Line 6 Interpreter Email Address",
#     "page": 5,
#     "coords": [
#       60.001,
#       354.002,
#       294.001,
#       372.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's email address in Part 4, Line 6.",
#     "examples": [
#       "interpreter@email.com"
#     ]
#   },
#   {
#     "field_id": "Pt4Line5_MobileNumber[0]",
#     "label": "Part 4 Line 5 Interpreter Mobile Phone Number",
#     "page": 5,
#     "coords": [
#       59.893,
#       390.002,
#       294.227,
#       408.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's mobile phone number in Part 4, Line 5.",
#     "examples": [
#       "555-777-8888"
#     ]
#   },
#   {
#     "field_id": "Part4_NameofLanguage[0]",
#     "label": "Part 4 Name of Language",
#     "page": 5,
#     "coords": [
#       144.0,
#       288.0,
#       289.998,
#       306.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the name of the language interpreted in Part 4.",
#     "examples": [
#       "SPANISH"
#     ]
#   },
#   {
#     "field_id": "Pt5Line1b_PreparerGivenName[0]",
#     "label": "Part 5 Line 1b Preparer Given Name",
#     "page": 5,
#     "coords": [
#       342.0,
#       569.996,
#       576.0,
#       587.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the given name of the person who prepared the form in Part 5, Line 1b.",
#     "examples": [
#       "ROBERT"
#     ]
#   },
#   {
#     "field_id": "Pt5Line2_BusinessName[0]",
#     "label": "Part 5 Line 2 Preparer Business Name",
#     "page": 5,
#     "coords": [
#       342.0,
#       533.999,
#       576.0,
#       551.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the business name of the person who prepared the form in Part 5, Line 2.",
#     "examples": [
#       "LEGAL AID SOCIETY"
#     ]
#   },
#   {
#     "field_id": "Pt5Line1a_PreparerFamilyName[0]",
#     "label": "Part 5 Line 1a Preparer Family Name",
#     "page": 5,
#     "coords": [
#       342.0,
#       605.996,
#       576.0,
#       623.996
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the family name of the person who prepared the form in Part 5, Line 1a.",
#     "examples": [
#       "WILLIAMS"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3c_CityOrTown[0]",
#     "label": "Part 6 Line 3c City or Town",
#     "page": 5,
#     "coords": [
#       402.001,
#       431.997,
#       576.0,
#       449.997
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town for the address in Part 6, Line 3c.",
#     "examples": [
#       "CHICAGO"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3a_StreetNumberName[0]",
#     "label": "Part 6 Line 3a Street Number and Name",
#     "page": 5,
#     "coords": [
#       407.999,
#       479.999,
#       576.0,
#       497.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the street number and name for the address in Part 6, Line 3a.",
#     "examples": [
#       "789 PINE ST"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3b_Unit[0]",
#     "label": "Part 6 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       425.999,
#       459.995,
#       435.999,
#       469.995
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 6, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3b_Unit[1]",
#     "label": "Part 6 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       342.0,
#       459.995,
#       352.0,
#       469.995
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 6, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3b_AptSteFlrNumber[0]",
#     "label": "Part 6 Line 3b Apt/Ste/Flr Number",
#     "page": 5,
#     "coords": [
#       468.0,
#       455.995,
#       576.0,
#       473.995
#     ],
#     "dependencies": [
#       "Pt6Line3b_Unit[0]",
#       "Pt6Line3b_Unit[1]",
#       "Pt6Line3b_Unit[2]"
#     ],
#     "gemini_note": "This field is for the apartment, suite, or floor number for the address in Part 6, Line 3b.",
#     "examples": [
#       "STE 303"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3b_Unit[2]",
#     "label": "Part 6 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       384.001,
#       459.998,
#       394.001,
#       469.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 6, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3g_PostalCode[0]",
#     "label": "Part 6 Line 3g Postal Code",
#     "page": 5,
#     "coords": [
#       402.174,
#       359.997,
#       575.87,
#       377.997
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the postal code for the address in Part 6, Line 3g.",
#     "examples": [
#       "60601"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3e_ZipCode[0]",
#     "label": "Part 6 Line 3e Zip Code",
#     "page": 5,
#     "coords": [
#       473.998,
#       407.999,
#       575.997,
#       425.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the zip code for the address in Part 6, Line 3e.",
#     "examples": [
#       "90210"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3d_State[0]",
#     "label": "Part 6 Line 3d State",
#     "page": 5,
#     "coords": [
#       365.998,
#       407.999,
#       401.998,
#       425.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the state for the address in Part 6, Line 3d.",
#     "examples": [
#       "CA"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3h_Country[0]",
#     "label": "Part 6 Line 3h Country",
#     "page": 5,
#     "coords": [
#       342.0,
#       324.0,
#       576.0,
#       342.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the country for the address in Part 6, Line 3h.",
#     "examples": [
#       "USA"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3f_Province[0]",
#     "label": "Part 6 Line 3f Province",
#     "page": 5,
#     "coords": [
#       402.174,
#       383.998,
#       575.87,
#       401.998
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the province for the address in Part 6, Line 3f.",
#     "examples": [
#       "ONTARIO"
#     ]
#   },
#   {
#     "field_id": "Pt5Line5_PreparerFaxNumber[0]",
#     "label": "Part 5 Line 5 Preparer Fax Number",
#     "page": 5,
#     "coords": [
#       342.0,
#       222.001,
#       576.0,
#       240.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the preparer's fax number in Part 5, Line 5.",
#     "examples": [
#       "555-444-3333"
#     ]
#   },
#   {
#     "field_id": "Pt5Line4_DaytimePhoneNumber1[0]",
#     "label": "Part 5 Line 4 Preparer Daytime Phone Number",
#     "page": 5,
#     "coords": [
#       342.0,
#       258.001,
#       576.0,
#       276.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the preparer's daytime phone number in Part 5, Line 4.",
#     "examples": [
#       "555-999-8888"
#     ]
#   },
#   {
#     "field_id": "Pt5Line6_Email[0]",
#     "label": "Part 5 Line 6 Preparer Email Address",
#     "page": 5,
#     "coords": [
#       342.0,
#       186.004,
#       576.0,
#       204.004
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the preparer's email address in Part 5, Line 6.",
#     "examples": [
#       "preparer@email.com"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3c_CityOrTown[0]",
#     "label": "Part 5 Line 3c City or Town",
#     "page": 5,
#     "coords": [
#       119.999,
#       600.001,
#       294.001,
#       618.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the city or town for the address in Part 5, Line 3c.",
#     "examples": [
#       "BOSTON"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3a_StreetNumberName[0]",
#     "label": "Part 5 Line 3a Street Number and Name",
#     "page": 5,
#     "coords": [
#       126.0,
#       648.003,
#       294.001,
#       666.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the street number and name for the address in Part 5, Line 3a.",
#     "examples": [
#       "101 PINE LANE"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3b_Unit[0]",
#     "label": "Part 5 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       144.0,
#       627.999,
#       154.0,
#       637.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3b_Unit[1]",
#     "label": "Part 5 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       60.001,
#       627.999,
#       70.001,
#       637.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3b_AptSteFlrNumber[0]",
#     "label": "Part 5 Line 3b Apt/Ste/Flr Number",
#     "page": 5,
#     "coords": [
#       186.001,
#       623.999,
#       294.001,
#       641.999
#     ],
#     "dependencies": [
#       "Pt5Line3b_Unit[0]",
#       "Pt5Line3b_Unit[1]",
#       "Pt5Line3b_Unit[2]"
#     ],
#     "gemini_note": "This field is for the apartment, suite, or floor number for the address in Part 5, Line 3b.",
#     "examples": [
#       "FLR 4"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3b_Unit[2]",
#     "label": "Part 5 Line 3b Unit Checkbox",
#     "page": 5,
#     "coords": [
#       101.999,
#       628.002,
#       111.999,
#       638.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 3b, likely related to an address unit type (Apt., Ste., Flr.).",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3g_PostalCode[0]",
#     "label": "Part 5 Line 3g Postal Code",
#     "page": 5,
#     "coords": [
#       120.214,
#       528.001,
#       293.876,
#       546.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the postal code for the address in Part 5, Line 3g.",
#     "examples": [
#       "B2T 1E2"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3e_ZipCode[0]",
#     "label": "Part 5 Line 3e Zip Code",
#     "page": 5,
#     "coords": [
#       191.999,
#       576.003,
#       293.998,
#       594.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the zip code for the address in Part 5, Line 3e.",
#     "examples": [
#       "02101"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3d_State[0]",
#     "label": "Part 5 Line 3d State",
#     "page": 5,
#     "coords": [
#       83.999,
#       576.003,
#       119.999,
#       594.003
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the state for the address in Part 5, Line 3d.",
#     "examples": [
#       "MA"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3h_Country[0]",
#     "label": "Part 5 Line 3h Country",
#     "page": 5,
#     "coords": [
#       60.001,
#       492.001,
#       294.001,
#       510.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the country for the address in Part 5, Line 3h.",
#     "examples": [
#       "CANADA"
#     ]
#   },
#   {
#     "field_id": "Pt5Line3f_Province[0]",
#     "label": "Part 5 Line 3f Province",
#     "page": 5,
#     "coords": [
#       120.214,
#       552.002,
#       293.876,
#       570.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the province for the address in Part 5, Line 3f.",
#     "examples": [
#       "QUEBEC"
#     ]
#   },
#   {
#     "field_id": "Pt4Line6b_DateofSignature[0]",
#     "label": "Part 4 Line 6b Interpreter Date of Signature",
#     "page": 5,
#     "coords": [
#       210.002,
#       114.001,
#       294.004,
#       132.001
#     ],
#     "dependencies": [
#       "Pt4Line6a_Signature[0]"
#     ],
#     "gemini_note": "This field is for the date the interpreter signed the form in Part 4, Line 6b.",
#     "examples": [
#       "03/07/2024"
#     ]
#   },
#   {
#     "field_id": "Pt4Line6a_Signature[0]",
#     "label": "Part 4 Line 6a Interpreter Signature",
#     "page": 5,
#     "coords": [
#       60.001,
#       138.002,
#       294.001,
#       156.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the interpreter's signature in Part 4, Line 6a.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 6,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Part5Line7_Checkbox[0]",
#     "label": "Part 5 Line 7 Checkbox",
#     "page": 6,
#     "coords": [
#       61.0,
#       637.001,
#       71.0,
#       647.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 7.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part5Line7_Checkbox[1]",
#     "label": "Part 5 Line 7 Checkbox",
#     "page": 6,
#     "coords": [
#       61.0,
#       595.0,
#       71.0,
#       605.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 7.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part5Line7b_Checkbox[0]",
#     "label": "Part 5 Line 7b Checkbox",
#     "page": 6,
#     "coords": [
#       79.0,
#       570.999,
#       89.0,
#       580.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 7b.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Part5Line7b_Checkbox[1]",
#     "label": "Part 5 Line 7b Checkbox",
#     "page": 6,
#     "coords": [
#       126.999,
#       570.999,
#       136.999,
#       580.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This is a checkbox field in Part 5, Line 7b.",
#     "examples": [
#       "Yes"
#     ]
#   },
#   {
#     "field_id": "Pt5Line8a_Signature[0]",
#     "label": "Part 5 Line 8a Preparer Signature",
#     "page": 6,
#     "coords": [
#       60.001,
#       281.993,
#       294.001,
#       299.993
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the preparer's signature in Part 5, Line 8a.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Pt5Line8b_DateofSignature[0]",
#     "label": "Part 5 Line 8b Preparer Date of Signature",
#     "page": 6,
#     "coords": [
#       210.002,
#       257.995,
#       294.004,
#       275.995
#     ],
#     "dependencies": [
#       "Pt5Line8a_Signature[0]"
#     ],
#     "gemini_note": "This field is for the date the preparer signed the form in Part 5, Line 8b.",
#     "examples": [
#       "03/07/2024"
#     ]
#   },
#   {
#     "field_id": "PDF417BarCode1[0]",
#     "label": "PDF417 Bar Code",
#     "page": 7,
#     "coords": [
#       191.999,
#       11.999,
#       461.999,
#       29.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the PDF417 barcode.",
#     "examples": [
#       ""
#     ]
#   },
#   {
#     "field_id": "Pt6Line3a_PageNumber[0]",
#     "label": "Part 6 Line 3a Page Number",
#     "page": 7,
#     "coords": [
#       60.001,
#       479.999,
#       114.001,
#       497.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the page number for the additional information in Part 6, Line 3a.",
#     "examples": [
#       "3"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3b_PartNumber[0]",
#     "label": "Part 6 Line 3b Part Number",
#     "page": 7,
#     "coords": [
#       150.001,
#       479.999,
#       204.001,
#       497.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the part number for the additional information in Part 6, Line 3b.",
#     "examples": [
#       "2"
#     ]
#   },
#   {
#     "field_id": "Pt6Line3c_ItemNumber[0]",
#     "label": "Part 6 Line 3c Item Number",
#     "page": 7,
#     "coords": [
#       240.001,
#       479.999,
#       294.001,
#       497.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the item number for the additional information in Part 6, Line 3c.",
#     "examples": [
#       "10"
#     ]
#   },
#   {
#     "field_id": "Pt6Line4a_PageNumber[0]",
#     "label": "Part 6 Line 4a Page Number",
#     "page": 7,
#     "coords": [
#       60.001,
#       246.002,
#       114.001,
#       264.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the page number for the additional information in Part 6, Line 4a.",
#     "examples": [
#       "4"
#     ]
#   },
#   {
#     "field_id": "Pt6Line4b_PartNumber[0]",
#     "label": "Part 6 Line 4b Part Number",
#     "page": 7,
#     "coords": [
#       150.001,
#       246.002,
#       204.001,
#       264.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the part number for the additional information in Part 6, Line 4b.",
#     "examples": [
#       "3"
#     ]
#   },
#   {
#     "field_id": "Pt6Line4c_ItemNumber[0]",
#     "label": "Part 6 Line 4c Item Number",
#     "page": 7,
#     "coords": [
#       240.001,
#       246.002,
#       294.001,
#       264.002
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the item number for the additional information in Part 6, Line 4c.",
#     "examples": [
#       "15"
#     ]
#   },
#   {
#     "field_id": "Pt6Line4d_AdditionalInfo[0]",
#     "label": "Part 6 Line 4d Additional Information",
#     "page": 7,
#     "coords": [
#       60.001,
#       60.001,
#       294.021,
#       240.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for additional information related to Part 6, Line 4d.",
#     "examples": [
#       "See attached for details."
#     ]
#   },
#   {
#     "field_id": "Pt6Line5a_PageNumber[0]",
#     "label": "Part 6 Line 5a Page Number",
#     "page": 7,
#     "coords": [
#       342.0,
#       708.001,
#       396.0,
#       726.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the page number for the additional information in Part 6, Line 5a.",
#     "examples": [
#       "5"
#     ]
#   },
#   {
#     "field_id": "Pt6Line5b_PartNumber[0]",
#     "label": "Part 6 Line 5b Part Number",
#     "page": 7,
#     "coords": [
#       432.0,
#       708.001,
#       486.0,
#       726.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the part number for the additional information in Part 6, Line 5b.",
#     "examples": [
#       "2"
#     ]
#   },
#   {
#     "field_id": "Pt6Line5c_ItemNumber[0]",
#     "label": "Part 6 Line 5c Item Number",
#     "page": 7,
#     "coords": [
#       522.0,
#       708.001,
#       576.0,
#       726.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the item number for the additional information in Part 6, Line 5c.",
#     "examples": [
#       "10"
#     ]
#   },
#   {
#     "field_id": "Pt6Line5d_AdditionalInfo[0]",
#     "label": "Part 6 Line 5d Additional Information",
#     "page": 7,
#     "coords": [
#       342.0,
#       576.0,
#       576.0,
#       702.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for additional information related to Part 6, Line 5d.",
#     "examples": [
#       "More information provided on a separate sheet."
#     ]
#   },
#   {
#     "field_id": "Pt6Line6a_PageNumber[0]",
#     "label": "Part 6 Line 6a Page Number",
#     "page": 7,
#     "coords": [
#       342.0,
#       528.001,
#       396.0,
#       546.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the page number for the additional information in Part 6, Line 6a.",
#     "examples": [
#       "6"
#     ]
#   },
#   {
#     "field_id": "Pt6Line6b_PartNumber[0]",
#     "label": "Part 6 Line 6b Part Number",
#     "page": 7,
#     "coords": [
#       432.0,
#       528.001,
#       486.0,
#       546.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the part number for the additional information in Part 6, Line 6b.",
#     "examples": [
#       "3"
#     ]
#   },
#   {
#     "field_id": "Pt6Line6c_ItemNumber[0]",
#     "label": "Part 6 Line 6c Item Number",
#     "page": 7,
#     "coords": [
#       522.0,
#       528.001,
#       576.0,
#       546.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the item number for the additional information in Part 6, Line 6c.",
#     "examples": [
#       "16"
#     ]
#   },
#   {
#     "field_id": "Pt6Line6d_AdditionalInfo[0]",
#     "label": "Part 6 Line 6d Additional Information",
#     "page": 7,
#     "coords": [
#       342.0,
#       360.0,
#       576.02,
#       522.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for additional information related to Part 6, Line 6d.",
#     "examples": [
#       "See continuation sheet."
#     ]
#   },
#   {
#     "field_id": "Pt6Line7a_PageNumber[0]",
#     "label": "Part 6 Line 7a Page Number",
#     "page": 7,
#     "coords": [
#       342.0,
#       312.001,
#       396.0,
#       330.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the page number for the additional information in Part 6, Line 7a.",
#     "examples": [
#       "7"
#     ]
#   },
#   {
#     "field_id": "Pt6Line7b_PartNumber[0]",
#     "label": "Part 6 Line 7b Part Number",
#     "page": 7,
#     "coords": [
#       432.0,
#       312.001,
#       486.0,
#       330.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the part number for the additional information in Part 6, Line 7b.",
#     "examples": [
#       "3"
#     ]
#   },
#   {
#     "field_id": "Pt6Line7c_ItemNumber[0]",
#     "label": "Part 6 Line 7c Item Number",
#     "page": 7,
#     "coords": [
#       522.0,
#       312.001,
#       576.0,
#       330.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the item number for the additional information in Part 6, Line 7c.",
#     "examples": [
#       "18"
#     ]
#   },
#   {
#     "field_id": "Pt6Line7d_AdditionalInfo[0]",
#     "label": "Part 6 Line 7d Additional Information",
#     "page": 7,
#     "coords": [
#       342.0,
#       126.0,
#       576.02,
#       306.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for additional information related to Part 6, Line 7d.",
#     "examples": [
#       "See Section 18b for further details."
#     ]
#   },
#   {
#     "field_id": "Line1a_FamilyName[0]",
#     "label": "Part 6 Line 1a Family Name",
#     "page": 7,
#     "coords": [
#       120.013,
#       594.0,
#       294.015,
#       612.0
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's family name repeated in Part 6, Line 1a.",
#     "examples": [
#       "SMITH"
#     ]
#   },
#   {
#     "field_id": "Line1b_GivenName[0]",
#     "label": "Part 6 Line 1b Given Name",
#     "page": 7,
#     "coords": [
#       119.999,
#       569.999,
#       294.001,
#       587.999
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's given name repeated in Part 6, Line 1b.",
#     "examples": [
#       "JOHN"
#     ]
#   },
#   {
#     "field_id": "Line1c_MiddleName[0]",
#     "label": "Part 6 Line 1c Middle Name",
#     "page": 7,
#     "coords": [
#       120.013,
#       546.001,
#       294.012,
#       564.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's middle name repeated in Part 6, Line 1c.",
#     "examples": [
#       "PAUL"
#     ]
#   },
#   {
#     "field_id": "Line7_AlienNumber[0]",
#     "label": "Part 6 Line 7 Alien Number",
#     "page": 7,
#     "coords": [
#       164.962,
#       521.997,
#       293.972,
#       539.997
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for the applicant's Alien Registration Number (A-Number) repeated in Part 6, Line 7.",
#     "examples": [
#       "A123456789"
#     ]
#   },
#   {
#     "field_id": "Pt6Line4d_AdditionalInfo[1]",
#     "label": "Part 6 Line 4d Additional Information",
#     "page": 7,
#     "coords": [
#       60.001,
#       294.001,
#       294.021,
#       474.001
#     ],
#     "dependencies": [],
#     "gemini_note": "This field is for additional information related to Part 6, Line 4d.",
#     "examples": [
#       "Further details provided below."
#     ]
#   }
# ]
